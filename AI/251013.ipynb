# %% [markdown]
# # ⭐ AI 수업 정리
# ### DAY1️⃣

# %% [markdown]
# ##### ✍️AI, ML, DL의 정의
#
# 1. AI(Artificial Intelligence)
# - 주어진 환경/데이터를 인지, 학습, 추론을 통해 목표 달성을 하도록 예측, 행동 선택, 계획하는 시스템
#
# 2. ML(Machine Learning)
# - AI 범주 내에서 데이터로부터 학습하여 목적을 달성하는 접근 방법론
# - 예 : 언어 모델, 이미지 분류 모델, 추천 시스템
#
# 3. DL(Deep Learning)
# - ML 범주 내에서 신경망(Neural Network) 함수를 사용한 학습 방법론
#
# 4. AI - ML (ML이 아닌 AI 시스템)의 예
# - 규칙 기반 시스템
# - 휴리스틱 기반 (최적화) 알고리즘
#
# ##### ✍️데이터 구성 요소(Feature / Label)
# 1. 데이터가 중요한 이유
# - 머신러닝은 규칙을 직접 코딩하지 않고, 데이터에서 규칙을 학습
# - 데이터(Feature, Label)의 분포와 관계가 머신러닝의 학습 결과를 결정
#
# 2. Feature(피처, 특성)
# - 모델이 예측에 사용하는 입력정보
# - 예측, 판단의 근거/단서
#
# 3. Label(라벨, 목표값)
# - 모델이 예측하려는 정답
# - 학습의 목표값
#
# ##### ✍️1D 피쳐 기반 학습
# 1. 1D = 1차원
# 2. Feature가 하나일 때 머신러닝이 학습하는 가장 단순한 형태
# - 학력에 따른 수입 -> 학력에 따라 수입의 형태가 달라지며, 수입에 영향을 주는 독립변수가 1개이다.
# ![image.png](./img/ai1.png)
# ![image.png](./img/ai2.png)
#
#
# ##### ✍️모델과 가설 공간
#
# 1. 학습(Learning)
# - 입력(Feature) → 출력(Label) 관계를 찾는 과정
# - 평균 관계를 하나의 함수로 표현함
# - 하지만 관계를 표현할 수 있는 함수는 무수히 많음
#
# 2. 가설 공간(Hypothesis Space)
# - 관계를 표현할 수 있는 모든 후보 함수들의 모음
# - 피쳐 공간과 라벨 공간 위에서 정의된 함수들의 집합 F
#
# 3. 모델(Model)
# - 가설공간 F에 속한 특정 함수 f
#
# ##### ✍️학습이란?
# - 주어진 데이터와 성능척도를 바탕으로 가설공간 F의 후보들 중 최적의 모델을 선택하는 과정
# - 데이터D → 가설공간F → 선택된 모델f
# ![image.png](./img/ai3.png)

# %% [markdown]
# ##### ✍️2D 피쳐 기반 학습
#
# ![image.png](./img/ai4.png)
#
# ![image.png](./img/ai5.png)

# %% [markdown]
# ### 🅰️일반적 용어 정리 및 모델 가정
#
# 1. Income = f*(Years of Education, Seniority,) + e → Y = f*(X)+e
# - Income : 우리가 예측하려는 라벨(반응/목표) 변수 → Y로 표기
# - Years of Education : 첫번째 피쳐(입력/예측) 변수 → X1으로 표기
# - Seniority : 두번째 피쳐(입력/예측) 변수 → X2로 표기
# - 다른 i번째 피처가 있다면 역시 Xi로 표기
# - 일반적인 p차원 피쳐(총 p개의 피쳐) 벡터: X = [X1, X2, ... ,Xp] R^p
# - 모델(함수형) : f^* : R^p → R, Y = f*(X)+e
# - 측정 오차 e: e는 피쳐 X와 독립 및 E[e] = 0 으로 가정함

# %% [markdown]
# # 🧑‍🏫지도학습
# 1. 데이터
# - 입력(특성)과 정답(라벨)이 쌍으로 있는 데이터
#
# 2. 목표
# - 새 입력이 들어오면 정답을 잘 맞추는 규칙을 학습
#
# 3. 지도학습의 종료
# - 회귀 : 예측값이 숫자(가격, 점수, 온도)
# - 분류 : 예측값이 범주(스팸/정상, 질병 유/무)
#
# ##### 🅰️지도학습 용어 정리
# 1. 특성(Feature, x)
# - 예측에 쓰는 설명 변수
#
# 2. 라벨(Lable, y)
# - 맞춰야 하는 정답
#
# 3. 예측값(y-hat)
# - 모델이 내놓은 결과(숫자 또는 범주)
#
# 4. 오류(Error)
# - 예측값과 라벨의 차이
#
# ### ✍️회귀 문제
# 1. 입력으로부터 숫자를 얼마나 정확히 예측할까?
# - Feature : 면적, 방수, 연식 → Label : 집값(원 단위)
# - Feature : 매체 별 광고비(TV/라디오/온라인) → Label : 매출액
#
# 2. 라벨 및 예측 모델의 출력
# - 연속적인 수치
#
# ##### ✍️회귀 오류 : 평균제곱오차(MSE)
# 1. 평균제곱오차(Mean Squared Error)
# - 각 데이터에서 정답과 예측의 평균 제곱 차이값
# ![image.png](./img/ai6.png)
#
# 2. 해석
# - 큰 오류를 더 크게 벌주므로, 전체 오류 수준을 한눈에 봄
#
# 3. 참고
# - 데이터와 같은 단위를 쓰고 싶으면 RMSE(MSE의 제곱근)도 사용
# ![image.png](./img/ai7.png)
#
# ##### ✍️회귀 설명력 : R^2(결정계수)
# 1. 결정계수
# - 라벨의 분산 중에서 특성으로 설명되는 비율
# - '평균만 쓰는 단순한 예측'보다 얼마나 더 잘 맞추는지를 0~1 사이로 나타낸 값
# ![image.png](./img/ai8.png)
#
# 2. 해석
# - 1에 가까울수록 설명력이 높고, 낮을수록 설명력이 낮음
#
# 3. 질문
# - R^2가 음수가 나올 수 있을까?
# → 음수가 나올 수 있음
# → 빨간 박스 부분이 1보다 큰 수가 나온다면 R^2 값이 음수가 나올 수 있음
# → 회귀 그래프를 제대로 그리지 못한 경우, 음수가 나올 수 있음
#
# ### ✍️분류 문제
# 1. 입력으로부터 범주는 얼마나 정확히 가려낼까?
# - Feature : 메일 내용, 보낸이 이메일주소 → Label : 스팸/정상
# - Feature : 종양 반경, 면적 → Label : 악성/양성
#
# 2. 라벨
# - 범주 라벨(이진/다중)
#
# ##### 분류 정확도(Accuracy)
# 1. 정확도
# - 전체 중 맞춘 비율
# ![image.png](./img/ai9.png)
#
# 2. 정확도만 보면 발생하는 문제
# - 데이터가 불균형할 경우, 정확도가 99%로 보일 수 있음
# - 예 : 불균형 데이터(양성 1%, 음성 99%)에서는 전부 음성이라 해도 정확도가 99%로 보일 수 있음
#
# 3. 결론
# - 정확도만 보지 말고 **다른 지표**도 함께 봐야 안전
#
# ##### ✍️혼동행렬(Confusion Matrix)
# 1. 예측과 실제 값 사이의 관계를 행렬 형태로 표현
# - TP : 실제 양성, 예측도 양성
# - TN : 실제 음성, 예측도 음성
# - FP : 실제는 음성인데 양성이라 함(오탐)
# - FN : 실제는 양성인데 음성이라 함(누락)
# ![image.png](./img/ai10.png)
#
# 2. 정밀도(Precision)
# - '양성이라 **판정한 것** 중' 진짜 양성의 비율 = TP/(TP+FP)
#
# 3. 재현율(Sensitivity or Recall)
# - '진짜 양성 **가운데**' 잡아낸 예측 양성 비율 = TP(TP+FN)
#
# 4. F1-score
# - 정밀도와 재현율의 조화평균
# ![image.png](./img/ai11.png)

# %% [markdown]
# ##### ✍️오버피팅이란?
# - 훈련 데이터의 우연한 패턴/잡음까지 외워버려서(초록색 함수), 훈련에서는 잘 맞지만 테스트에서는 성능이 나빠지는 현상
# - 현상 : 휸련 오류 급격히 낮음, 테스트 오류 높음/요동
# ![image.png](./img/ai12.png)
#
# **오버피팅이 왜 안 좋은가?**
# - **표본(sample) 의존, 불안정** : 훈련 데이터는 모집단의 일부 표본이라 우연한 잡음이 섞임. 이 것에만 과하게 맞추어 학습하면 샘플 몇 개만 바뀌어도 예측이 크게 흔들림(분산↑)
# - **일반화 실패** : 보지 못한 데이터(테스트) 오류가 커짐, 모집단 성능과 격차가 벌어짐
#
# ##### ✍️오버피팅에 대한 오해
# 1. **오버피팅 != 분표 변화(distribution shift)로 인한 에러 증가**
# - **분포 변화로 인한 오류** : 훈련 데이터 분포와 테스트 분포가 다름으로(환경, 계절, 센서 변경 등) 성능이 떨어지는 현상
# - **분포 변화**로 인한 에러 증가는 모델이 과적합하지 않아도 발생가능
# ![image.png](./img/ai13.png)
# - ❗ 위 그림과 같이, 훈련 데이터는 실제 고양이와 강아지 사진으로 하였으나 테스트는 일러스트 이미지로 대체할 경우, 데이터의 분포가 달라지므로 과적합 문제가 아닌 데이터 분포 변화 문제로 인하여 에러가 발생함.
#
# ##### 오버피팅 VS 언더피팅
# 1. 오버피팅 VS 언더피팅(균형 잡기)
# - 오버피팅 : 모델이 너무 복잡 → 잡음까지 학습(테스트 성능 나쁨)
# - 언더피팅 : 모델이 단순하거나 학습이 완료되지 않음 → 중요한 패턴을 놓침(오류 큼)
#
# 2. 해결 실마리
# - 더 많은 데이터, 테스트 데이터를 활용한 모델 선정, 교차 검증(3차시)
# ![image.png](./img/ai14.png)

# %% [markdown]
# ##### ✍️테스트 성능 평가
# 1. ✏️훈련 오류 VS 테스트 오류
# - **훈련 오류** : 모델을 학습시킨 **같은 데이터**에 다시 적용해 계산한 오류
# - **테스트 오류** : 학습에 쓰지 않은 **새 관측치**에 대해 모델을 적용했을 때의 평균 예측 오류
# - 보통 훈련 오류는 테스트 오류와 다르며, 특히 훈련 오류는 테스트 오류를 (심하게) 과소평가하는 경우가 많음
# ![image.png](./img/ai15.png)
# - 훈련오차(Training Error)
# → 고양이 이미지를 학습 데이터로 사용했는데, 모델이 고양이를 "Dog"로 잘못 분류하고 있음.
# - 테스트오차(Test Error)
# → 새로운 고양이(테스트 데이터)에 대해 예측했더니 역시 "Dog"로 잘못 예측함.
# - 이 그림은, 모델이 훈련 데이터에서도 틀리고 새로운 데이터에서도 틀릴 수 있음을 보여주며, “훈련오류 vs 테스트오류”의 개념적 차이를 시각적으로 표현함.
# - 모델의 진짜 성능을 판단하려면 테스트 오류를 봐야 함.
#
# 💡 요약
# 구분|	의미	|데이터 종류|	특징|
# |--|--|--|--|
# 훈련 오류|	학습 데이터에서의 오류|	학습에 사용한 데이터	|과소평가 가능 (낮게 나옴)|
# 테스트 오류	|새로운 데이터에서의 오류|	학습에 사용하지 않은 데이터	|실제 성능 평가에 적합
#
# ![image.png](./img/ai16.png)
# - 파란색 선 : 훈련 오류
# - 빨간색 선 : 테스트 오류
# - 훈련 오류는 계속↓, 테스트 오류는 U자형
# - 목적 : 테스트 오류의  U자형의 바닥이 되도록 하는 적절한 모델 찾기
#
# 2. ✏️테스트 예측오류 계산
# - 이상적 케이스 : 충분히 큰 별도 테스트 데이터셋 → 현실에선 구하기 어려움
# - 현실에서는 테스트만을 위한 데이터를 갖기에 데이터 자체가 부족할 수 있음
#
# 3. 대안 : 재표본화(resampling)를 통한 테스트 오류 추정
# - 방법 : 검증셋(hold-out), K겹 교차검증(K-fold Cross-Validation)
# - 장점 : 별도의 테스트 데이터 없이 **데이터를 더 효율적으로 사용**하여 일반화 오차 추정
#
#
# ##### ✍️검증셋(Validation Set) 접근
# 1. ✏️검증셋(홀드아웃) 방법
# - 가용 샘플들을 무작위로 **훈련셋**과 **검증셋(hold-out)**으로 분할
# - 훈련셋으로 **모델 적합**, 검증셋으로 **예측** 후 **검증 오류**를 계산
# - 검증 오류는 보통 **정량 반응**은 **MSE**, **범주 반응**은 **오분류율(또는 F1-score)**을 측정한다.
# ![image.png](./img/ai17.png)
#
# 1-1. 검증 절차
# - 데이터 순서 무작위 셔플링 후 두 부분으로 분할 : 왼쪽(파랑) = 훈련셋, 오른쪽(주황) = 검증셋
# - 학습은 훈련셋에서, 성능평가는 검증셋에서 수행
# ![image.png](./img/ai18.png)
#
# 1-2. 예시) 자동차 데이터
# - 목표 : 선형(1차)모델 부터 고차항(다항식) 모델 비교
# - 392개 데이터를 무작위로 196개 훈련셋/196개 검증셋으로 분할 (일반적으로 반으로 나눌 필요는 없음)
# - 좌측 패널 : 단 한 번 분할 시의 MSE 곡선
# - 우측 패널 : 여러 번 (셔플 후) 다른 분할의 MSE 곡선들
# ![image.png](./img/ai19.png)
# **예시에서 보이는 검증셋 방법이 단점이 무엇일까?**
# - 어떤 표본이 훈련/검증에 들어가느냐에 따라 검증 기반 테스트 오류 추정치가 매우 가변적
# - 검증 접근에서는 훈련셋(=전체의 일부)만으로 모델을 적합하므로, 전체 데이터로 학습했을 때보다 성능이 낮게 추정(즉, 테스트 오류를 과대 추정)될 수 있음
#
# **왜 전체 데이터로 학습한 모델의 테스트 오류를 과대 추정하는 경향이 있을까?**
# → 학습에 데이터를 부분만 사용하기 때문
# ![image.png](./img/ai20.png)
#
# 2. ✏️K-겹 교차검증
# - 테스트 오류 추정의 표준적 접근
# - 추정치는 모델 선택과 최종 모델의 테스트 오류 규모 파악에 활용
# - 데이터 전체를 동일한 크기 K개 폴드로 무작위 분할
# → 폴드 k E {1, 2, ..., k}를 검증, 나머지 K-1개를 훈련에 사용
# - k = 1, ..., k에 대해 반복 후, 평균 오류로 테스트 오류를 추정
# ![image.png](./img/ai21.png)
#
# 2-1. K-겹 교차검증 단계
# - 데이터를 먼저 셔플링한 뒤, 총 n개의 데이터를 겹치지 않는 K개 그룹으로 분할
# - 각 그룹이 번갈아 검증셋(주황), 나머지는 훈련셋(파랑)
# - K개의 MSE를 평균해 테스트 오류를 추정
#
# 2-2. K-겹 교차검증 오류 계산
# - 폴드 집합 C1,...,Ck, 각 폴드 크기 Nk
# ![image.png](./img/ai22.png)
#
# 3. ✏️Leave-One-Out 교차 검증
# - 훈련셋(파랑) : 고나측치 하나만 제외한 나머지 전부
# - 검증셋(주황) : 제외한 1개 관측치
# - 이과정을 n번 반복해 나온 n개의 MSE 평균으로 테스트 오류를 추정
# ![image.png](./img/ai23.png)
#
# 3-1. Leave-One-Out 교차검증 VS 10-겹 교차검증
# - 자동차 데이터에서 LOOCV와 10-겹 CV 결과 비교 (다항 차수에 따른 MSE 곡선)
# - 두 방법의 경향과 최적 차수가 비슷
# ![image.png](./img/ai24.png)
#
# 3-2. 시뮬레이션 : 참/추정 테스트 MSE
# - 파랑 : 참(test) MSE, 검은 점선 : LOOCV 추정, 주황 : 10-겹 CV 추정
# - 10-겹 CV 추정 : 테스트 성능에 추정의 좋은 대안
# ![image.png](./img/ai25.png)

# %% [markdown]
# # 🧑‍🏫비지도 학습
# 1. 비지도 학습이란?
# - 정의 : 레이블(정답) 없이 데이터의 구조, 패턴, 집단(잠재 서브그룹)을 찾아내는 학습
# - 대표과제 : 군집화(clustering), 차원축소(PCA 등), 밀도추정 / 이상치 탐지
# - 출력 : '정답 예측'이 아니라 구조/요약/표현(embedding)
#
# 2. 핵심질문
# - 무엇을 비슷함/다름으로 볼 것인가(거리, 유사도 선택)
# - 전처리(스케일 표준화 등)을 어떻게 할 것이낙
# - 출력 : '정답 예측'이 아니라 구조/요약/표현(embedding)
#
# 3. 비지도 VS 지도학습
# - 지도 학습 : 입력+라벨로 예측 모델 학습
# → 예 : 가격 예측, 악성 종양 예측
#
# - 비지도 학습 : 입력만으로 구조 학습
# → 예 : 고객 세그먼트
# → 클러스터링 : 서로 비슷한 데이터끼리 묶어 동질 그룹 만들기
# ![image.png](./img/ai26.png)
# → 백화점에서 결제 금액에 따라 고객을 분류하여 등급을 매기는 것과 같이 고객의 특성에 맞게 동질 그룹을 만듬
# → 해당 과정을 거치게 되면, 분류된 고객에 따라 어떠한 마케팅을 하면 좋은지, 어떠한 상품을 선호하는지 알 수 있음
#
#
# ##### 클러스터링(Clustering)
# ❗ 어떤 군집이 먼저 묶이느냐에 따라 최종 구조가 바뀔 수 있음
#
# 1. 클러스터링이란?
# - 클러스터링 : 데이터 안에서 하위 집단(클러스터)을 찾는 기법들의 총칭
# - 목표 : 집단 내부는 서로 유사, 집단 간은 상이하도록 데이터를 분할
# - 유사/상이 정도는 도메인 맥락에 따라 정의가 달라질 수 있음
# - 문제, 데이터 특성에 의존
#
# 2. 예시) 마케팅 세그먼테이션
# - 다수의 지표(가구 소득, 직업, 도심 거리 등)를 가진 많은 사람들에 대해 특정 광고/상품에 더 반응할 하위집단을 식별하고자 함
# - 시장 세분화 작업 자체가 클러스터링에 해당
# ![image.png](./img/ai27.png)
#
# 3. 대표 클러스터링 기법
# - K-평균(K-means) : K(클러스터 수)를 미리 정해 분할
# - 계층적 군집(Hierarchical) : K를 사전에 고정하지 않음
# ![image.png](./img/ai28.png)
#
# ##### K-means 클러스터링 - 비계층적 군집화
# 1. K-means 클러스터링 결과 예시
# - 패널 : K = 2, 3, 4에서 각 K-means결과(점 색상 = 할당된 클러스터)
# - 클러스터 결과에서 특정 색상은 의미가 없고, 점들이 다른 색이라는 것은 서로 다른 클러스터에 속해 있다는 의미
# ![image.png](./img/ai29.png)
#
# 2. K-means의 표기(군집 집합)
# ![image.png](./img/ai30.png)
# - K-means의 핵심 아이디어
# - 좋은 군집화 = 클러스터 내부 변동(Within-Cluster Variation)이 작은 분할
# - 목표 : 클러스터 내부 변동의 합이 최소가 되도록 분할을 찾음
# - 모든 클러스터의 내부 흩어짐 총합이 가장 작은 분할
#
# 3. K-means 알고리즘
# - 초기화 : 관측치들에 무작위로 1...K 클러스터를 임시 부여
# - 반복(할당이 더 이상 바뀌지 않을 때까지) :
#     → 각 클러스터의 중심(centroid) 계산(특성 평균 벡터)
#     → 각 관측치를 가장 가까운 중심의 클러스터에 재할당(거리 예=유클리드)
#
# 4. K-means 알고리즘 특성
# - 위 반복은 매 단계 목표함수 값을 감소시킴(군집 내 평균 제곱거리의 성질 때문)
# - 단, 전역(global) 최솟값 보장은 아님 → 초기값에 따라 지역 최솟값으로 수렴 가능
# ![image.png](./img/ai31.png)
# - K개의 군집화를 진행하면서, 무작위 클러스터 초기화 이후 중심을 재계산함
# - 중심 계산을 하였을 때, 이전 값과 다르면(중심의 위치가 달라지고 있으면) 클러스터 재배정을 반복함
# - 만약, 중심 계산을 하였을 때 이전 값과 같다면, 해당 반복을 종료하고 중심 값을 출력함
#
# 5. 다른 초기값의 영향
# - 서로 다른 초기 레이블에서 최종 분할과 목표값(패널 상단 숫자)이 달라짐
# - 초기화의 중요성 : 여러 번 시도 권장
# ![image.png](./img/ai32.png)
# - Within-Cluster Variation이 작게 나와야 좋은 군집화가 되었다고 할 수 있음
# - ❗따라서, 여러 번 시도하여 최솟값이 나올 수 있도록 해야 함
#
# ##### 계층적 군집(Hierarchical Clustering) - 계층적 군집화
# 1. K-means 클러스터링 VS 계층적 군집
# - K-means는 클러스터 수 K를 미리 지정해야 하는 단점이 존재함
# - 계층적 군집은 K를 고정하지 않고 전체 구조를 덴드로그램으로 제공
# - 이번 강의에서는 상향식(agglomerative)을 다룸 : 잎→몸통 으로 병합
# - K-means는 상위 군집 개념이 없기 때문에 포함 관계가 생기지 않지만, 계층적 군집은 포함관계가 있음
#
# 구분|	K-means|	계층적 군집|
# |--|--|--|
# 군집 구조	|평면적 (flat)|	계층적 (hierarchical)|
# 포함관계|	❌ 없음|	✅ 있음|
# 결과 형태|	k개의 고정된 군집	|덴드로그램(트리 구조)|
# 주된 사용	|빠른 분할, 대규모 데이터	|군집 관계 탐색, 시각적 분석|
#
# 2. 계층적 군집 결과 예시
# - 덴드로그램에서 수평선 높이(거리)를 기준으로 가위질하여 K개 군집을 얻음
# ![image.png](./img/ai33.png)
#
# 3. 계층적 군집 알고리즘(상향식)
# - n개 관측에 대해 쌍별 비유사도 계산, 각 관측치를 하나의 클러스터로 시작
# - i개 클러스터 간 쌍별 비유사도를 모두 계산해 가장 유사한 두 클러스터를 병합
# - 병합 후 남은 i-1개 클러스터 사이의 새 비유사도를 다시 계산
# ![image.png](./img/ai34.png)
# - 처음은 각각 개별로 클러스터를 만듬
# - 그 다음 가까운 클러스터들끼리 먼저 묶음
# - 모든 클러스터들이 하나로 뭉쳐질 때까지 해당 과정을 반복함
#
#
# 4. 계층적 군집 병합 진행
# - 데이터들이 점차 큰 클러스터로 합쳐지는 과정
# - 매 단계에서 클러스터들끼리의 병합이 이루어짐
# - 1개의 단일 클러스터가 될 때까지 진행
# **계층적 군집의 계산량** : 매 단계에서 모든 클러스터 쌍 간의 거리를 계산해야 함. 데이터의 수가 많은 경우 K-means에 비하여 계산량이 많음
#
# 5. 링크(link)의 유형
# - Single(최소 거리) 링크 : 두 개 클러스터 내 데이터 쌍 별 거리 중 최소값을 군집 간 거리로
# - Complete(최대 거리) 링크 : 두 개 클러스터 내 데이터 쌍별 거리 중 최대값을 군집 간 거리로
# - Average(평균 거리) 링크 : 두 개 클러스터 내 데이터 쌍별 거리의 평균을 군집 간 거리로
# ![image.png](./img/ai35.png)
#
# 링크 유형	|거리 계산 기준	|특징	|군집 형태|
# |--|--|--|--|
# Single Link	|두 군집 간 최소 거리|	연쇄적 구조, 노이즈에 약함	|길고 가늘다
# Complete Link|	두 군집 간 최대 거리	|조밀, 이상치에 강함	|둥글고 조밀함
# Average Link	|두 군집 간 평균 거리	|균형 잡힘, 안정적	|중간 형태
#
# 6. 링크에 따라 결과가 달라진다
# - 같은 데이터라도 링크 선택에 따라 클러스터링 결과(덴드로그램)가 달라질 수 있음
# - 하나의 링크만 시도하는 것이 아니라 다른 종류의 링크도 사용 권장
# ![image.png](./img/ai36.png)
#
# ##### ❗ 클러스터링 시 주의점
# 1. 클러스터링 체크리스트
# - 스케일링 : 표준화 (평균 0, 표준편차 1로 입력 변수 변환)가 필요한가?
# → Yes, 변수 단위 차이 영향 큼
# - 몇 개의 클러스터가 적합한가?
# → K-means, 계층적 모두 어려운 문제, 합의된 정답 없음
# - 단일 시도가 아닌 여러 번 시도 권장됨
